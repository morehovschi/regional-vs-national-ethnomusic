# %%
import py2lispIDyOM as py2lispIDyOM
from py2lispIDyOM.run import IDyOMExperiment

# %%
my_experiment = IDyOMExperiment(test_dataset_path='deps/py2lispIDyOM/tutorials/dataset/bach_dataset',
                                pretrain_dataset_path='deps/py2lispIDyOM/tutorials/dataset/shanx_dataset')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 my_experiment = IDyOMExperiment(test_dataset_path='deps/py2lispIDyOM/tutorials/dataset/bach_dataset',
#       2                                 pretrain_dataset_path='deps/py2lispIDyOM/tutorials/dataset/shanx_dataset')
#
# File <string>:8, in __init__(self, test_dataset_path, pretrain_dataset_path, experiment_history_folder_path, experiment_logger_name, idyom_config)
#
# File /opt/miniconda3/envs/ethno/lib/python3.11/site-packages/py2lispIDyOM/run.py:36, in IDyOMExperiment.__post_init__(self)
#      35 def __post_init__(self):
# ---> 36     self.logger = ExperimentLogger(pretrain_dataset_path=self.pretrain_dataset_path,
#      37                                    test_dataset_path=self.test_dataset_path,
# ...

# %%
my_experiment.set_parameters(target_viewpoints=['cpitch', 'onset'],
                             source_viewpoints=['cpitch', 'onset'],
                             models=':both',
                             k=1,
                             detail=3)

# %%
my_experiment.run()
# Out:
# ** running lisp script **
# To load "clsql":
#   Load 1 ASDF system:
#     clsql
# ; Loading "clsql"
#
# To load "clsql":
#   Load 1 ASDF system:
#     clsql
# ; Loading "clsql"
#
# To load "idyom":
#   Load 1 ASDF system:
#     idyom
# ; Loading "idyom"
# ..........
#
# Inserting data into database: dataset 66041125211838.
# Inserting data into database: dataset 99041125211838.
# Written resampling set to /Users/morehovschi/idyom/data/resampling/66041125211838-1.resample.
# Written PPM* model to /Users/morehovschi/idyom/data/models/cpitch_99041125211838_66041125211838-1:1_melody.ppm.
# Written PPM* model to /Users/morehovschi/idyom/data/models/onset_99041125211838_66041125211838-1:1_melody.ppm.
#
# ** Finished! **

# %%
# !ls data/\(dis\)similarities-22/MIDI_files/FS_MIDI/FS_MIDI_ROMANIA/romani20.mid
# Out:
# data/(dis)similarities-22/MIDI_files/FS_MIDI/FS_MIDI_ROMANIA/romani20.mid

# %%
test_path = 'data/dissimilarities-22/MIDI_files/FS_MIDI/FS_MIDI_ROMANIA'
print("Files in test dataset directory:", os.listdir(test_path) )
# Out:
# Files in test dataset directory: ['romani01.mid', 'romani14.mid', 'romani28.mid', 'romani02.mid', 'romani16.mid', 'romani17.mid', 'romani03.mid', 'romani07.mid', 'romani13.mid', 'romani12.mid', 'romani06.mid', 'romani10.mid', 'romani05.mid', 'romani11.mid', 'romani20.mid', 'romani09.mid', 'romani22.mid', 'romani26.mid', 'romani27.mid', 'romani25.mid', 'romani19.mid', 'romani18.mid', 'romani24.mid']

# %%
# !ls inter-data/borsan-midi-for-real/ | wc -l
# Out:
#      236
